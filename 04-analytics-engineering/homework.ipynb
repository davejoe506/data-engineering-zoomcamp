# %% [markdown]
# ## Homework #3
# ###  Question 1

# %% [markdown]
# My solution (int_trips_unioned only) does not require any code.

# %% [markdown]
# ###  Question 2

# %% [markdown]
# My solution (dbt fails the test with non-zero exit code) does not require any code.

# %% [markdown]
# ###  Question 3

# %% [markdown]
# My solution (12,184) contains SQL, so please see README.

# %% [markdown]
# ###  Question 4

# %% [markdown]
# My solution (East Harlem North) contains SQL, so please see README.

# %% [markdown]
# ###  Question 5

# %% [markdown]
# My solution (384,624) contains SQL, so please see README.

# %% [markdown]
# ###  Question 6

# %% [markdown]
# My solution (43,244,693) contains SQL, so please see README.
