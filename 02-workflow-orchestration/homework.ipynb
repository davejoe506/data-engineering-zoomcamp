# %% [markdown]
# ## Homework #2
# ###  Question 1

# %% [markdown]
# My solution (128.3 MiB) does not contain any code and was deduced from looking at the Kestra UI after running the 05_postgres_taxi_scheduled.yaml file from lecture.

# %% [markdown]
# ###  Question 2

# %% [markdown]
# My solution (green_tripdata_2020-04.csv) does not contain any code and was deduced from looking at the 05_postgres_taxi_scheduled.yaml file from lecture.

# %% [markdown]
# ###  Question 3

# %% [markdown]
# My solution (24,648,499) contains SQL, so please see README.

# %% [markdown]
# ###  Question 4

# %% [markdown]
# My solution (1,734,051) contains SQL, so please see README.

# %% [markdown]
# ###  Question 5

# %% [markdown]
# My solution (1,925,152) contains SQL, so please see README.

# %% [markdown]
# ###  Question 6

# %% [markdown]
# My solution (Add a timezone property set to America/New_York in the Schedule trigger configuration) does not contain any code and was deduced from looking at the [Kestra Schedule Trigger Documentation](https://kestra.io/docs/workflow-components/triggers/schedule-trigger).
