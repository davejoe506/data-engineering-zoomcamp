# %% [markdown]
# ## Homework #3
# ###  Question 1

# %% [markdown]
# My solution (20,332,093) contains SQL, so please see README.

# %% [markdown]
# ###  Question 2

# %% [markdown]
# SQL was used to calculate my solution (0 MB for the External Table and 155.12 MB for the Materialized Table), so please see README.

# %% [markdown]
# ###  Question 3

# %% [markdown]
# My solution (BigQuery is a columnar database, and it only scans the specific columns requested in the query. Querying two columns (PULocationID, DOLocationID) requires reading more data than querying one column (PULocationID), leading to a higher estimated number of bytes processed.) does not require any code.

# %% [markdown]
# ###  Question 4

# %% [markdown]
# My solution (8,333) contains SQL, so please see README.

# %% [markdown]
# ###  Question 5

# %% [markdown]
# My solution (Partition by tpep_dropoff_datetime and Cluster on VendorID) contains SQL (please see README) and was also deduced by looking at the lecture materials.

# %% [markdown]
# ###  Question 6

# %% [markdown]
# SQL was used to calculate my solution (310.24 MB for non-partitioned table and 26.84 MB for the partitioned table), so please see README.

# %% [markdown]
# ###  Question 7

# %% [markdown]
# My solution (GCP Bucket) does not require any code.

# %% [markdown]
# ###  Question 8

# %% [markdown]
# My solution (False) does not require any code.

# %% [markdown]
# ###  Question 9

# %% [markdown]
# My solution is written in the submission form.
